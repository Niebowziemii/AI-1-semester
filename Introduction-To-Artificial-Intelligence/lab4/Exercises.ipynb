# %% [markdown]
# # Shortest Hamiltonian path problem

# %% [markdown]
# Shortest Hamiltonian path problem is a little bit simpler version of the problem __Travelling Salesman Problem (TSP)__
# where we are not looking for a __cycle__ passing through all the nodes (cities) and we are satisfied with the shortest __path__ connecting all cities. We don't have to go back to the start city.

# %% [markdown]
# There are N cities. Given is a distance matrix M=NxN, where $M[i][j]$ is a distance from the i-th to the j-th city.
# In this exercise, we consider a symmetrical variant of shortest Hamiltonian path problem, i.e., $M[i][j] = M[j][i]$. Furhermore, $M[i][i] = 0$.
# The objective is to find the __shortest path traversing through each city once__. In other words: <br> Let s=[3,1,...,5] be some N-element permutation of indices. We want to find such a permutation that $\sum_{k=2,...,N}M[s[k-1]][s[k]]$ is optimal (minimal).

# %% [markdown]
# This exercise consists of three parts. Finish the first part to get a mark of 3.0; the first two parts for 4.0. Complete all three parts to get 5.0.

# %% [markdown]
# # Part 1: Evolutionary algorithm

# %%
import common as cm
import numpy as np
import matplotlib.pyplot as plt
import random as rn
# %matplotlib inline

# %% [markdown]
# ### 1.1) Evaluation

# %% [markdown]
# Complete the below function. It should evaluate an input solution (decision vector, vector of indices) in terms of TSP distance criterion. M is a distance matrix. Return the computed total distance.

# %%
def getEvaluation(solution, M):
    distance = 0
    for i in range(len(solution)-1):
        distance+=M[solution[i]][solution[i+1]]
    return distance

M = cm.getTutorialDistanceMatrix() ### 6 CITIES
print(getEvaluation([0,1,2,3,4,5], M)) 
print(getEvaluation([5,4,3,2,1,0], M))
print(getEvaluation([0,2,1,3,5,4], M))
# Out:
# 174.32598574155733
# 174.32598574155733
# 328.20779166053677

# %% [markdown]
# ### 1.2) Validation

# %% [markdown]
# This function can be used to validate the solution, i.e., to check if a given solution vector is of a proper size and to check if each element is unique.

# %%
def isValid(solution, cities):
    if len(solution) != cities: return False
    s = set(solution)
    e = set([i for i in range(cities)])
    if s==e: return True
    else: return False
    
print(isValid([0,1,2,3,4,5,6], 6)) # FALSE
print(isValid([0,1,2,3,4,5], 6)) # TRUE
print(isValid([0,1,2,3,4,5,5], 6)) # FALSE
print(isValid([0,1,1,2,3,2], 6)) # FALSE
# Out:
# False
# True
# False
# False

# %% [markdown]
# ### 1.3) Initialization

# %% [markdown]
# We need to create a population of solutions. These solutions - initially - can be generated randomly.
# Firstly, complete getRandomSolution function (cities = the number of cities considered in the TSP problem).
# It should generate a random permutation of [0,1,...,cities] vector. You can use np.random.shuffle function. Then,
# finish getInitialPopulation method. It should return a populationSize-element vector of pairs [distance, solution], where a solution is a random permutation of indices, and distance = the total distance (solution evaluation).

# %%
def getRandomSolution(cities):
    s = [i for i in range(cities)]
    rn.shuffle(s)
    return s

def getInitialPopulation(populationSize, cities, M):
    population = []
    for i in range(populationSize):
        sol = getRandomSolution(cities)
        dist = getEvaluation(sol,M)
        population.append([sol,dist])
    return population

def printPopulation(population):
    for s in population:
        print(str(s[0]) + " : " + str(s[1]))

population = getInitialPopulation(10, 6, M)
printPopulation(population)
# Out:
# [1, 4, 3, 0, 5, 2] : 269.38939057411426
# [2, 3, 0, 4, 5, 1] : 261.4735980146131
# [4, 3, 1, 5, 2, 0] : 371.5489877629266
# [4, 3, 0, 2, 1, 5] : 345.6900409531655
# [0, 5, 4, 2, 3, 1] : 252.33221851374333
# [4, 2, 3, 5, 0, 1] : 247.8009898019179
# [2, 4, 1, 5, 0, 3] : 295.3288901178179
# [1, 5, 4, 0, 2, 3] : 264.51096114158645
# [4, 1, 5, 0, 2, 3] : 277.3651241784589
# [5, 2, 1, 3, 4, 0] : 281.96893426353756

# %% [markdown]
# ### 1.4) Sort population

# %% [markdown]
# The below function should sort the population according to the distance, i.e., according to the first element of each pair. These should be ordered from the smallest to the largest.You can use .sort method and a lambda function.

# %%
def sortPopulation(population):
    population.sort(key=lambda x: x[1])
    return population


printPopulation(sortPopulation(population))
# Out:
# [4, 2, 3, 5, 0, 1] : 247.8009898019179
# [0, 5, 4, 2, 3, 1] : 252.33221851374333
# [2, 3, 0, 4, 5, 1] : 261.4735980146131
# [1, 5, 4, 0, 2, 3] : 264.51096114158645
# [1, 4, 3, 0, 5, 2] : 269.38939057411426
# [4, 1, 5, 0, 2, 3] : 277.3651241784589
# [5, 2, 1, 3, 4, 0] : 281.96893426353756
# [2, 4, 1, 5, 0, 3] : 295.3288901178179
# [4, 3, 0, 2, 1, 5] : 345.6900409531655
# [4, 3, 1, 5, 2, 0] : 371.5489877629266

# %% [markdown]
# ### 1.5) Summarize the population

# %% [markdown]
# The below function should compute minimum, mean, and maximum value of the total distances of solutions in the population. Return these statistics as [min, mean, max] vector.

# %%
def getStats(population):
    mini=min(population,key=lambda x: x[1])
    maxi=max(population,key=lambda x: x[1])
    mean=(mini[1]+maxi[1])/2
    return [mini[1],mean,maxi[1]]

print(getStats(population))
# Out:
# [247.8009898019179, 309.67498878242225, 371.5489877629266]

# %% [markdown]
# ### 1.6) Tournament selection of size K

# %% [markdown]
# You are asked to implement a tournament for parent selection (it is assumed that the population is already sorted). Firstly, complete getTournamentSelection method. It should return index corresponding to selected parent solution. Simply generate random permutation of integers from [0,...,populationSize], take K first elements and select the smallest index (as the solutions are ordered from the best to the worst). Repeat this process twice and return a vector [index1, index2]. Then, complete getMatingPool method. Usually, matingPoolSize = population size, i.e., we wish to generate an offspring population of size populationSize and thus we need to select such many pairs of parent solutions. This metod should return a vector of these pairs, e.g., [[2, 5], [9, 2], ..., [5, 7]].

# %%
def getTournamentSelection(populationSize, K):
    tab = [i for i in range(populationSize)]
    rn.shuffle(tab)
    choose=tab[:K]
    parent=min(choose)
    return parent
    
def getParentIndices(populationSize, K):
    parents = []
    for i in range(2):
        parents.append(getTournamentSelection(populationSize, K))
    return parents
    
def getMatingPool(matingPoolSize, populationSize, K):
    matingPool = []
    for i in range(matingPoolSize):
        matingPool.append(getParentIndices(populationSize,K))
    return matingPool
     
matingPool = getMatingPool(10, 10, 2)
print(matingPool)
# print(getTournamentSelection(10,2))
# Out:
# [[2, 6], [2, 6], [5, 3], [2, 2], [1, 2], [2, 3], [5, 5], [0, 2], [0, 4], [2, 1]]

# %% [markdown]
# How does the selection depend on K? Run the below code for different K and verify your thoughts.
#
#
# The higher K the better solutions

# %%
def testTournament(matingPoolSize, populationSize, K):
    testMatingPool = getMatingPool(matingPoolSize, populationSize, K)
    cm.displayHistogram(plt, np, testMatingPool, populationSize)
    
testTournament(10000, 10, 1)
testTournament(10000, 10, 2)
testTournament(10000, 10, 3)
testTournament(10000, 10, 5)

# %% [markdown]
# ### 1.7) Crossover operator

# %% [markdown]
# Now, you are asked to implement the crossover operator. A and B are solutions (decision vectors). Let child be a new offspring solution (decision vector) and N is the number of cities.  Assume that the first N/2 elements of the child vector = the first N/2 elements of A, while the last N/2 elements of the child vector = the last N/2 elements of B. Obviously, such constructed solution may not be valid (use isValid) method. Repair this. You can, e.g., check (i) which indices are duplicated and (ii) which indices are missing. Then, you can replace one copy of each duplicate with one random missing index.

# %%
def getCrossedOver(A, B):
    child = A.copy()
    N = len(A)
    child = A[:round(N/2)]+B[round(N/2):]
    if isValid(child, N): return child
    
    solution=set(child)
    permutation=set(A)
    braki=list(permutation.difference(solution))
    rn.shuffle(braki)
    ilosci=[0 for i in range(len(child))]
    for i in range(len(child)):
            ilosci[child[i]]+=1
    for i in range(len(child)):
        if ilosci[child[i]]==2:
            child[i]=braki[0]
            del braki[0]
            if not isValid(child, N):
                continue
            elif isValid(child,N):
                return child

### TEST
print(getCrossedOver([0,1,2,3,4,5,6],[6,5,4,1,2,3,0]))
# Out:
# [5, 1, 4, 6, 2, 3, 0]

# %% [markdown]
# ### 1.8) Mutation operator

# %% [markdown]
# Implement the mutation operator. Simply swap two different random cities (indices). Apply this mutation with a certain probability (input argument).

# %%
def mutate(solution, probability):
    if np.random.random() < probability:
        a=int(rn.uniform(0,len(solution)))
        b=int(rn.uniform(0,len(solution)))
#         print(a,b)
        solution[a],solution[b]=solution[b],solution[a]
for i in range(10):
    s= [0,1,2,3,4,5]
    mutate(s, 0.9)
    print(s)
# Out:
# [0, 1, 4, 3, 2, 5]
# [4, 1, 2, 3, 0, 5]
# [5, 1, 2, 3, 4, 0]
# [0, 1, 2, 4, 3, 5]
# [4, 1, 2, 3, 0, 5]
# [5, 1, 2, 3, 4, 0]
# [0, 1, 2, 3, 4, 5]
# [0, 1, 3, 2, 4, 5]
# [2, 1, 0, 3, 4, 5]
# [0, 1, 2, 4, 3, 5]

# %% [markdown]
# ### 1.9) Create offspring

# %% [markdown]
# Now, combine both operators. The below method should generate the offspring. For each pair of parent indices in matingPool, i.e., [index1, index2], take the corresponding solutions from the population and apply the crossover and mutation operators in order to generate a single offspring/child. Evaluate this solution, i.e., compute the total distance. Finally, add [distance, child] to children vector.

# %%
def getOffspring(population, matingPool, mutationProbability, M):
    children = []
    for pair in matingPool:
        child=getCrossedOver(population[pair[0]][0],population[pair[1]][0])
#         print(population,population[pair[0]][0],population[pair[1]][0])
        mutate(child,mutationProbability)
        ch=[]
        ch.append(child)
        ch.append(getEvaluation(child,M))
        children.append(ch)
    return children

# %% [markdown]
# ### 1.10) Evolutionary Algorithm

# %% [markdown]
# Now, you are asked to combine all the previously completed methods into an evolutionary algorithm. This is the outline of the algorithm: <br>
# 1) Create an initial population of size "populationSize" <br>
# 2) Sort the population <br>
# 3) Construct a mating pool <br>
# 4) Generate an offspring of size "populationSize" <br>
# 5) Merge the current population and the offspring <br>
# 6) Sort such merged population <br>
# 7) Remove the worst half of the population or a better approach is to use tournament selection (run populationSize times) <br>
# 8) Go to (2) until the stopping criterion is not meet (repeat for the assumed number of generations) <br>
#
# In each generation, compute & display the statistics concerning the current population. Finally, what is the best solution found by the method? Rerun the method for different parameters (e.g., population size) and check if you can improve the result.

# %%
costMatrix = cm.getTutorialDistanceMatrix() ### 6 CITIES
cities = 6
mutationProbability = 1.0/6.0
populationSize4 = 20
generations = 50
K=2
population4 = getInitialPopulation(populationSize4, cities, costMatrix)
population4 = sortPopulation(population4)

for g in range(generations):
    population4 = sortPopulation(population4)
    matingPool4 = getMatingPool(populationSize4, populationSize4, K)
    offspring4 = getOffspring(population4, matingPool4, mutationProbability, costMatrix)
    population4+=offspring4
    population4 = sortPopulation(population4)
    buffer=[]
    for i in range(populationSize4):
        buffer.append(population4[getTournamentSelection(populationSize4, K)])
    population4=buffer
    if g>0:
        print("generation_number: [min,mean,max]",g,getStats(population4))
print("After several tests, the best solution is\"168.71883981362282\" ")
# Out:
# generation_number: [min,mean,max] 1 [172.8430844949571, 191.74792919918818, 210.65277390341925]
# generation_number: [min,mean,max] 2 [172.8430844949571, 183.35518458653934, 193.8672846781216]
# generation_number: [min,mean,max] 3 [172.8430844949571, 183.35518458653934, 193.8672846781216]
# generation_number: [min,mean,max] 4 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 5 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 6 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 7 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 8 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 9 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 10 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 11 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 12 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 13 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 14 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 15 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 16 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 17 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 18 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 19 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 20 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 21 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 22 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 23 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 24 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 25 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 26 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 27 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 28 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 29 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 30 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 31 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 32 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 33 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 34 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 35 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 36 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 37 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 38 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 39 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 40 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 41 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 42 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 43 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 44 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 45 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 46 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 47 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 48 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# generation_number: [min,mean,max] 49 [172.8430844949571, 172.8430844949571, 172.8430844949571]
# After several tests, the best solution is"168.71883981362282"

# %% [markdown]
# # Part 2: Visualization of convergence

# %% [markdown]
# 2.1) Now, change the data set (distance matrix) to cm.getLargeDistanceMatrix. This instance concerns 15 cities. Run the evolutionary algorithm with a population size of 20 and the number of generation of 200 (and suitably adjust the mutation probability - 1.0/15.0). In each generation, store the statistics (min, mean, and max distances found, in, respectively, Y_MIN, Y_MEAN, Y_MAX). Then, use cm.plotConvergence(plt, X, Y_MIN, Y_MEAN, Y_MAX) to display the convergence plot. Rerun the code for different parameters and observe the results. What is the best value (distance) you could find (print)?

# %%
dataSetForPart2 = cm.getLargeDistanceMatrix() #15 cities
populationSizeForPart2 = 20
numberOfGenerationsForPart2 = 200
mutationProbabilityForPart2 = 1.0/15.0
citiesForPart2 = 15
K=2
populationForPart2 = getInitialPopulation(populationSizeForPart2, citiesForPart2, dataSetForPart2)

populationForPart2 = sortPopulation(populationForPart2)

data = [[],[],[]]

for g in range(numberOfGenerationsForPart2):
    populationForPart2 = sortPopulation(populationForPart2)
    matingPoolForPart2 = getMatingPool(populationSizeForPart2, populationSizeForPart2, K)
    offspringForPart2 = getOffspring(populationForPart2, matingPoolForPart2, mutationProbabilityForPart2, dataSetForPart2)
    populationForPart2+=offspringForPart2
    populationForPart2 = sortPopulation(populationForPart2)
    buffer=[]
    for i in range(populationSizeForPart2):
        buffer.append(populationForPart2[getTournamentSelection(populationSizeForPart2, K)])
    populationForPart2=buffer
    Y_MIN, Y_MEAN, Y_MAX = getStats(populationForPart2)
    data[0].append(Y_MIN)
    data[1].append(Y_MEAN)
    data[2].append(Y_MAX)
print("Best value: ", min(data[0]))
gen = [i for i in range(numberOfGenerationsForPart2)]
cm.plotConvergence(plt,gen, data[0], data[1], data[2])
# Out:
# Best value:  403.2910244563487

# %% [markdown]
# 2.2) Each time you rerun the code, while keeping the paramet values fixed, the results my slightly change. This is due to the random nature of evolutionary algorithms. Hence, in order to get the reliable results, the method must be run several times and the results have to be averaged. Do the following:<br>
# - run the method 20 times <br>
# - in each run: capture the best result found  throughout evolutionary search (i.e., in each generation) <br>
# - for each generation: find min, mean, and max value over 20 independent runs <br>
# - use cm.plotConvergence to display the convergence
# - print the best value ever found

# %%
best_values = []

for i in range(20):
    dataSetForPart2 = cm.getLargeDistanceMatrix() #15 cities
    populationSizeForPart2 = 20
    numberOfGenerationsForPart2 = 200
    mutationProbabilityForPart2 = 1.0/15.0
    citiesForPart2 = 15
    K=2
    populationForPart2 = getInitialPopulation(populationSizeForPart2, citiesForPart2, dataSetForPart2)

    populationForPart2 = sortPopulation(populationForPart2)

    data = [[],[],[]]

    for g in range(numberOfGenerationsForPart2):
        populationForPart2 = sortPopulation(populationForPart2)
        matingPoolForPart2 = getMatingPool(populationSizeForPart2, populationSizeForPart2, K)
        offspringForPart2 = getOffspring(populationForPart2, matingPoolForPart2, mutationProbabilityForPart2, dataSetForPart2)
        populationForPart2+=offspringForPart2
        populationForPart2 = sortPopulation(populationForPart2)
        buffer=[]
        for i in range(populationSizeForPart2):
            buffer.append(populationForPart2[getTournamentSelection(populationSizeForPart2, K)])
        populationForPart2=buffer
        Y_MIN, Y_MEAN, Y_MAX = getStats(populationForPart2)
        data[0].append(Y_MIN)
        data[1].append(Y_MEAN)
        data[2].append(Y_MAX)
    
    best_values.append(min(data[0]))
    gen = [i for i in range(numberOfGenerationsForPart2)]
    cm.plotConvergence(plt,gen, data[0], data[1], data[2])

print("Best value: ", min(best_values))
# Out:
# Best value:  318.18704816992175

# %% [markdown]
# # Part 3: Impact of different parameter values on the optimization

# %% [markdown]
# In this exercise, you are asked to check how the method performs when involving different parameter values. Firtly, we wish to plot several convergence plots in a single chart. For this reason, you may copy & paste the cm.plotConvergence function (from common.py) and modify it. Then, copy & paste the code you completed in the previous exercise (the one which averages 20 trial runs). Then: <br>
# - Firsty, evaluate the performance in terms of different population sizes. Specifically, check how the method performs for the population size = 5, 10, 20, and 50. Display 4 convergence plots in a signle chart.
# - Secondly, evaluate the performance in terms of different tournament sizes. Specifically, check how the method performs for the tournament size = 1, 2, 5, and 15. Display 4 convergence plots in a signle chart.

# %%
def plotConvergence2(plt, X, Y_MINs, Y_MEANs, Y_MAXs):
    fig, ax = plt.subplots(1, 1)
    ax.fill_between(X, Y_MINs[0], Y_MAXs[0], alpha=0.5)
    ax.fill_between(X, Y_MINs[1], Y_MAXs[1], alpha=0.5)
    ax.fill_between(X, Y_MINs[2], Y_MAXs[2], alpha=0.5)
    ax.fill_between(X, Y_MINs[3], Y_MAXs[3], alpha=0.5)
    ax.plot(X, Y_MEANs[0], linestyle='-', color="black")
    ax.plot(X, Y_MEANs[1], linestyle='-', color="green")
    ax.plot(X, Y_MEANs[2], linestyle='-', color="blue")
    ax.plot(X, Y_MEANs[3], linestyle='-', color="pink")
    plt.xlabel('Generation')
    plt.ylabel('Total distance')
    plt.grid(True)

# %%
Y_MINs = []
Y_MEANs = []
Y_MAXs = []
for population_size in [5,10,20,50]:
    dataSetForPart2 = cm.getLargeDistanceMatrix() #15 cities
    populationSizeForPart2 = population_size
    numberOfGenerationsForPart2 = 200
    mutationProbabilityForPart2 = 1.0/15.0
    citiesForPart2 = 15
    K=2
    populationForPart2 = getInitialPopulation(populationSizeForPart2, citiesForPart2, dataSetForPart2)

    populationForPart2 = sortPopulation(populationForPart2)

    data = [[],[],[]]

    for g in range(numberOfGenerationsForPart2):
        populationForPart2 = sortPopulation(populationForPart2)
        matingPoolForPart2 = getMatingPool(populationSizeForPart2, populationSizeForPart2, K)
        offspringForPart2 = getOffspring(populationForPart2, matingPoolForPart2, mutationProbabilityForPart2, dataSetForPart2)
        populationForPart2+=offspringForPart2
        populationForPart2 = sortPopulation(populationForPart2)
        buffer=[]
        for i in range(populationSizeForPart2):
            buffer.append(populationForPart2[getTournamentSelection(populationSizeForPart2, K)])
        populationForPart2=buffer
        Y_MIN, Y_MEAN, Y_MAX = getStats(populationForPart2)
        data[0].append(Y_MIN)
        data[1].append(Y_MEAN)
        data[2].append(Y_MAX)
    
    best_values.append(min(data[0]))
    Y_MINs.append(data[0])
    Y_MEANs.append(data[1])
    Y_MAXs.append(data[2])
    
gen = [i for i in range(numberOfGenerationsForPart2)]
plotConvergence2(plt,gen, Y_MINs, Y_MEANs, Y_MAXs)

# %%
Y_MINs = []
Y_MEANs = []
Y_MAXs = []

for k in [1,2,5,15]:
    dataSetForPart2 = cm.getLargeDistanceMatrix() #15 cities
    populationSizeForPart2 = 20
    numberOfGenerationsForPart2 = 200
    mutationProbabilityForPart2 = 1.0/15.0
    citiesForPart2 = 15
    K=k
    populationForPart2 = getInitialPopulation(populationSizeForPart2, citiesForPart2, dataSetForPart2)

    populationForPart2 = sortPopulation(populationForPart2)

    data = [[],[],[]]

    for g in range(numberOfGenerationsForPart2):
        populationForPart2 = sortPopulation(populationForPart2)
        matingPoolForPart2 = getMatingPool(populationSizeForPart2, populationSizeForPart2, K)
        offspringForPart2 = getOffspring(populationForPart2, matingPoolForPart2, mutationProbabilityForPart2, dataSetForPart2)
        populationForPart2+=offspringForPart2
        populationForPart2 = sortPopulation(populationForPart2)
        buffer=[]
        for i in range(populationSizeForPart2):
            buffer.append(populationForPart2[getTournamentSelection(populationSizeForPart2, K)])
        populationForPart2=buffer
        Y_MIN, Y_MEAN, Y_MAX = getStats(populationForPart2)
        data[0].append(Y_MIN)
        data[1].append(Y_MEAN)
        data[2].append(Y_MAX)
        
    best_values.append(min(data[0]))
    Y_MINs.append(data[0])
    Y_MEANs.append(data[1])
    Y_MAXs.append(data[2])
    
gen = [i for i in range(numberOfGenerationsForPart2)]
plotConvergence2(plt,gen, Y_MINs, Y_MEANs, Y_MAXs)
